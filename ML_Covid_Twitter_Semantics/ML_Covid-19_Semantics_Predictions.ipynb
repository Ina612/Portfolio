# %% [markdown]
# # Predict tweet sentiment
#
# #### Data:
# about 45,000 tweets about COVID 19 collected in 2020 manually labelled with sentiments.
#
# **corona_train.csv** contains tweets with the target variable (Sentiment) included. We will use the data to train the models and check their quality.
#
# **corona_test.csv** contains tweets without associated values of the target variable. We will predict sentiments for every tweet from this file.
#
# #### Quality measure:
# accuracy

# %% [markdown]
# ## 1. Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_palette('muted')
sns.set_color_codes('muted')
sns.set_style('white')

import warnings
warnings.filterwarnings('ignore')

import re
import nltk
nltk.download('wordnet')

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import ParameterGrid
from tqdm import tqdm
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.svm import SVC

nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to /home/zarina/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/zarina/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/zarina/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /home/zarina/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/zarina/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ## 2. Upload the files and look through them

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
train = pd.read_csv('corona_train.csv', encoding='ISO-8859-1', index_col=0)
test = pd.read_csv('corona_test.csv', encoding='ISO-8859-1', index_col=0)
train.head(10)
# Out:
#     UserName  ScreenName                   Location     TweetAt  \
# ID
# 0       3801       48753                  Vagabonds  16-03-2020
# 1       3802       48754                        NaN  16-03-2020
# 2       3804       48756  ÃT: 36.319708,-82.363649  16-03-2020
# 3       3807       48759            Atlanta, GA USA  16-03-2020
# 4       3808       48760           BHAVNAGAR,GUJRAT  16-03-2020
# 5       3809       48761             Makati, Manila  16-03-2020
# 6       3810       48762  Pitt Meadows, BC, Canada   16-03-2020
# 7       3811       48763                 Horningsea  16-03-2020
# 8       3813       48765                        NaN  16-03-2020
# 9       3814       48766             Houston, Texas  16-03-2020
#
#                                         OriginalTweet           Sentiment
# ID
# 0   Coronavirus Australia: Woolworths to give elde...            Positive
# 1   My food stock is not the only one which is emp...            Positive
# 2   As news of the regions first confirmed COVID-1...            Positive
# 3   Due to COVID-19 our retail store and classroom...            Positive
# 4   For corona prevention,we should stop to buy th...            Negative
# 5   All month there hasn't been crowding in the su...             Neutral
# 6   Due to the Covid-19 situation, we have increas...  Extremely Positive
# 7   #horningsea is a caring community. Lets ALL lo...  Extremely Positive
# 8   ADARA Releases COVID-19 Resource Center for Tr...            Positive
# 9   Lines at the grocery store have been unpredict...            Positive

# %%
train['type']='train'
test['type']='test'
test['Sentiment']=''

# %%
train=train.append(test)

# %%
train.drop_duplicates(subset='OriginalTweet').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44955 entries, 0 to 17981
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UserName       44955 non-null  int64
#  1   ScreenName     44955 non-null  int64
#  2   Location       35531 non-null  object
#  3   TweetAt        44955 non-null  object
#  4   OriginalTweet  44955 non-null  object
#  5   Sentiment      44955 non-null  object
#  6   type           44955 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 2.7+ MB

# %%
train.UserName = train.UserName.astype(str)
train.ScreenName = train.ScreenName.astype(str)

# %%
train.describe()
# Out:
#        UserName ScreenName       Location     TweetAt  \
# count     44955      44955          35531       44955
# unique    44955      44955          13127          44
# top        3801      48753  United States  20-03-2020
# freq          1          1            603        3448
#
#                                             OriginalTweet Sentiment   type
# count                                               44955     44955  44955
# unique                                              44955         6      2
# top     Coronavirus Australia: Woolworths to give elde...            train
# freq                                                    1     17982  26973

# %%
train.TweetAt = pd.to_datetime(train.TweetAt)

# %%
train.TweetAt.loc[0]
# Out:
# ID
# 0   2020-03-16
# 0   2020-07-04
# Name: TweetAt, dtype: datetime64[ns]

# %%
# tweets_per_day
tweets_per_day = train[['TweetAt']].set_index(train['TweetAt']).resample('D').count()
tweets_per_day
# Out:
#             TweetAt
# TweetAt
# 2020-01-04      630
# 2020-01-05        0
# 2020-01-06        0
# 2020-01-07        0
# 2020-01-08        0
# ...             ...
# 2020-11-30        0
# 2020-12-01        0
# 2020-12-02        0
# 2020-12-03      685
# 2020-12-04      803
#
# [336 rows x 1 columns]

# %%
# tweets_per_day_simple  strftime
tweets_per_day_simple = train.TweetAt.dt.strftime('%m-%d').value_counts().sort_index()
tweets_per_day_simple
# Out:
# 01-04     630
# 02-03       4
# 02-04     954
# 03-03       4
# 03-04     810
# 03-13    1233
# 03-14     614
# 03-15     519
# 03-16    1128
# 03-17    1977
# 03-18    2742
# 03-19    3215
# 03-20    3448
# 03-21    2653
# 03-22    2114
# 03-23    2062
# 03-24    1480
# 03-25    2979
# 03-26    1277
# 03-27     345
# 03-28      23
# 03-29     125
# 03-30      87
# 03-31     316
# 04-03       8
# 04-04     767
# 04-13    1428
# 04-14     284
# 05-03       6
# 05-04    1131
# 06-03       2
# 06-04    1742
# 07-03       7
# 07-04    1843
# 08-03       9
# 08-04    1881
# 09-03      16
# 09-04    1471
# 10-03      54
# 10-04    1005
# 11-03     165
# 11-04     909
# 12-03     685
# 12-04     803
# Name: TweetAt, dtype: int64

# %%
train.Location.value_counts()
# Out:
# United States                  603
# London, England                568
# London                         565
# New York, NY                   429
# Washington, DC                 411
#                               ...
# MD/DC                            1
# Lenoir, N.C.                     1
# Hopefully not Garden Center      1
# Adn                              1
# Mahwah, NJ                       1
# Name: Location, Length: 13127, dtype: int64

# %%
train['month'] = train.TweetAt.dt.month
train['day'] = train.TweetAt.dt.day
train['dayofweek'] = train.TweetAt.dt.dayofweek
train['weekday'] = train.TweetAt.dt.weekday

# %%
train.dayofweek.value_counts()
# Out:
# 2    7442
# 4    7315
# 1    7061
# 3    6935
# 5    6584
# 0    5849
# 6    3769
# Name: dayofweek, dtype: int64

# %%
train['tweetlength'] = train.OriginalTweet.str.len()

# %% [markdown]
# ## 3. Clean the tweets

# %%
def tweet_cleaner(tweet):
    
    # remove urls
    tweet = re.sub(r'http\S+', ' ', tweet)
    
    # remove html tags
    #tweet = re.sub(r'<.*?>', ' ', tweet)
    
    # remove digits
    #tweet = re.sub(r'\d+', ' ', tweet)
    
    # remove hashtags
    tweet = re.sub(r'#\w+', ' ', tweet)
    
    # remove mentions
    tweet = re.sub(r'@\w+', ' ', tweet)
    
    # remove whitespaces
    tweet = ' '.join(tweet.split())

    return tweet
    
 
train['OriginalTweet'] = train['OriginalTweet'].apply(lambda x: tweet_cleaner(x)) 
train['CleanTweet'] = train['OriginalTweet'].apply(lambda x: x.replace('\n', ' '))
train['CleanTweet'] = train['CleanTweet'].str.lower()

# %% [markdown]
# ## 4. Lemmatization

# %%
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# %%
wnl = WordNetLemmatizer()

def lemmatize_text(text):
    # Split the text into words
    words = nltk.word_tokenize(text)
    # Lemmatize each word and join them back into a string
    return ' '.join([wnl.lemmatize(word, get_wordnet_pos(word)) for word in words])

# Apply the lemmatization function to the text data
train['CleanTweet'] = train['CleanTweet'].apply(lemmatize_text)

# %%
def cleaning_repeating_char(text):
    return re.sub(r'(.)1+', r'1', text)
train['CleanTweet'] = train['CleanTweet'].apply(lambda x: cleaning_repeating_char(x))

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44955 entries, 0 to 17981
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UserName       44955 non-null  object
#  1   ScreenName     44955 non-null  object
#  2   Location       35531 non-null  object
#  3   TweetAt        44955 non-null  datetime64[ns]
#  4   OriginalTweet  44955 non-null  object
#  5   Sentiment      44955 non-null  object
#  6   type           44955 non-null  object
#  7   month          44955 non-null  int64
#  8   day            44955 non-null  int64
#  9   dayofweek      44955 non-null  int64
#  10  weekday        44955 non-null  int64
#  11  tweetlength    44955 non-null  int64
#  12  CleanTweet     44955 non-null  object
# dtypes: datetime64[ns](1), int64(5), object(7)
# memory usage: 5.8+ MB

# %%
train['OriginalTweet'][1]
# Out:
# ID
# 1    My food stock is not the only one which is emp...
# 1    In light of Covid-19, Canada's insurers are re...
# Name: OriginalTweet, dtype: object

# %% [markdown]
# ## 5. Split the dataset

# %%
X_train_text, X_test_text, y_train_text, y_test_text = train_test_split(train[['CleanTweet']], 
                                                                        train.Sentiment,
                                                                        stratify=train.Sentiment,
                                                                        test_size = 0.25,
                                                                        random_state = 42)

# %%
len(X_train_text)
# Out:
# 33716

# %% [markdown]
# ## DecisionTreeClassifier

# %%
# here, we just check the decision trees on our data
# it's unlikely that we will use this model further

from sklearn.model_selection import ParameterGrid
from sklearn.pipeline import Pipeline
from tqdm import tqdm
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
        
params_grid = dict(min_df=[.0001, .0005, .0007, .001, .005, .01], max_df=[.7, .75, .8, .85, .9])

resultsdtc = []

for params in tqdm(ParameterGrid(params_grid)):
    pipe = Pipeline(steps = [
        ('tf_idf_vec', TfidfVectorizer(
            token_pattern=r'[A-Za-z]{2,}',
            max_df=params['max_df'],
            min_df=params['min_df'],
            stop_words='english'
        )), 
        ('classifier', DecisionTreeClassifier())
    ])
    
    pipe.fit(X_train_text['CleanTweet'], y_train_text)
    
    pipe_preds_train = pipe.predict(X_train_text.CleanTweet)
    pipe_preds_test = pipe.predict(X_test_text.CleanTweet)
    
    resultsdtc.append(dict(
        params=params,
        
        precision_train=precision_score(y_true=y_train_text, y_pred=pipe_preds_train, average='macro'),
        precision_test=precision_score(y_true=y_test_text, y_pred=pipe_preds_test, average='macro'),       
        
        recall_train=recall_score(y_true=y_train_text, y_pred=pipe_preds_train, average='macro'),
        recall_test=recall_score(y_true=y_test_text, y_pred=pipe_preds_test, average='macro'),
        
        f1_train=f1_score(y_true=y_train_text, y_pred=pipe_preds_train, average='macro'),
        f1_test=f1_score(y_true=y_test_text, y_pred=pipe_preds_test, average='macro'),
    
        accuracy_train=accuracy_score(y_true=y_train_text, y_pred=pipe_preds_train),
        accuracy_test=accuracy_score(y_true=y_test_text, y_pred=pipe_preds_test)
    ))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 30/30 [05:30<00:00, 11.03s/it]

# %%
resultsdtc = pd.DataFrame(resultsdtc)
resultsdtc.sort_values('accuracy_test', ascending=False).head(10).style.bar(vmin=0, vmax=1)
# Out:
# <style type="text/css">
# #T_5b176_row0_col1, #T_5b176_row1_col1, #T_5b176_row3_col1, #T_5b176_row4_col1, #T_5b176_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 99.5%, transparent 99.5%);
# }
# #T_5b176_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.6%, transparent 29.6%);
# }
# #T_5b176_row0_col3, #T_5b176_row1_col3, #T_5b176_row2_col1, #T_5b176_row3_col3, #T_5b176_row4_col3, #T_5b176_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 99.1%, transparent 99.1%);
# }
# #T_5b176_row0_col4, #T_5b176_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 28.1%, transparent 28.1%);
# }
# #T_5b176_row0_col5, #T_5b176_row1_col5, #T_5b176_row3_col5, #T_5b176_row4_col5, #T_5b176_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 99.3%, transparent 99.3%);
# }
# #T_5b176_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 28.7%, transparent 28.7%);
# }
# #T_5b176_row0_col7, #T_5b176_row1_col7, #T_5b176_row3_col7, #T_5b176_row4_col7, #T_5b176_row5_col1, #T_5b176_row6_col1, #T_5b176_row7_col7, #T_5b176_row8_col1, #T_5b176_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 99.2%, transparent 99.2%);
# }
# #T_5b176_row0_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.5%, transparent 33.5%);
# }
# #T_5b176_row1_col2, #T_5b176_row5_col2, #T_5b176_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.4%, transparent 29.4%);
# }
# #T_5b176_row1_col4, #T_5b176_row8_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 28.0%, transparent 28.0%);
# }
# #T_5b176_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 28.5%, transparent 28.5%);
# }
# #T_5b176_row1_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.4%, transparent 33.4%);
# }
# #T_5b176_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.7%, transparent 29.7%);
# }
# #T_5b176_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.7%, transparent 98.7%);
# }
# #T_5b176_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 28.2%, transparent 28.2%);
# }
# #T_5b176_row2_col5, #T_5b176_row5_col7, #T_5b176_row6_col7, #T_5b176_row8_col7, #T_5b176_row9_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.9%, transparent 98.9%);
# }
# #T_5b176_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 28.8%, transparent 28.8%);
# }
# #T_5b176_row2_col7, #T_5b176_row5_col3, #T_5b176_row6_col3, #T_5b176_row8_col3, #T_5b176_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.8%, transparent 98.8%);
# }
# #T_5b176_row2_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.3%, transparent 33.3%);
# }
# #T_5b176_row3_col2, #T_5b176_row6_col2, #T_5b176_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.1%, transparent 29.1%);
# }
# #T_5b176_row3_col4, #T_5b176_row4_col4, #T_5b176_row5_col4, #T_5b176_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 27.8%, transparent 27.8%);
# }
# #T_5b176_row3_col6, #T_5b176_row4_col6, #T_5b176_row7_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 28.3%, transparent 28.3%);
# }
# #T_5b176_row3_col8, #T_5b176_row4_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.1%, transparent 33.1%);
# }
# #T_5b176_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.2%, transparent 29.2%);
# }
# #T_5b176_row5_col5, #T_5b176_row6_col5, #T_5b176_row8_col5, #T_5b176_row9_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 99.0%, transparent 99.0%);
# }
# #T_5b176_row5_col6, #T_5b176_row9_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 28.4%, transparent 28.4%);
# }
# #T_5b176_row5_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.0%, transparent 33.0%);
# }
# #T_5b176_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 27.5%, transparent 27.5%);
# }
# #T_5b176_row6_col8, #T_5b176_row7_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 32.9%, transparent 32.9%);
# }
# #T_5b176_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.0%, transparent 29.0%);
# }
# #T_5b176_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 27.4%, transparent 27.4%);
# }
# #T_5b176_row8_col8, #T_5b176_row9_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 32.8%, transparent 32.8%);
# }
# #T_5b176_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 27.7%, transparent 27.7%);
# }
# </style>
# <table id="T_5b176">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b176_level0_col0" class="col_heading level0 col0" >params</th>
#       <th id="T_5b176_level0_col1" class="col_heading level0 col1" >precision_train</th>
#       <th id="T_5b176_level0_col2" class="col_heading level0 col2" >precision_test</th>
#       <th id="T_5b176_level0_col3" class="col_heading level0 col3" >recall_train</th>
#       <th id="T_5b176_level0_col4" class="col_heading level0 col4" >recall_test</th>
#       <th id="T_5b176_level0_col5" class="col_heading level0 col5" >f1_train</th>
#       <th id="T_5b176_level0_col6" class="col_heading level0 col6" >f1_test</th>
#       <th id="T_5b176_level0_col7" class="col_heading level0 col7" >accuracy_train</th>
#       <th id="T_5b176_level0_col8" class="col_heading level0 col8" >accuracy_test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b176_level0_row0" class="row_heading level0 row0" >12</th>
#       <td id="T_5b176_row0_col0" class="data row0 col0" >{'max_df': 0.8, 'min_df': 0.0001}</td>
#       <td id="T_5b176_row0_col1" class="data row0 col1" >0.994848</td>
#       <td id="T_5b176_row0_col2" class="data row0 col2" >0.296388</td>
#       <td id="T_5b176_row0_col3" class="data row0 col3" >0.990851</td>
#       <td id="T_5b176_row0_col4" class="data row0 col4" >0.280781</td>
#       <td id="T_5b176_row0_col5" class="data row0 col5" >0.992835</td>
#       <td id="T_5b176_row0_col6" class="data row0 col6" >0.286844</td>
#       <td id="T_5b176_row0_col7" class="data row0 col7" >0.992289</td>
#       <td id="T_5b176_row0_col8" class="data row0 col8" >0.334727</td>
#     </tr>
#     <tr>
#       <th id="T_5b176_level0_row1" class="row_heading level0 row1" >24</th>
#       <td id="T_5b176_row1_col0" class="data row1 col0" >{'max_df': 0.9, 'min_df': 0.0001}</td>
#       <td id="T_5b176_row1_col1" class="data row1 col1" >0.994848</td>
#       <td id="T_5b176_row1_col2" class="data row1 col2" >0.294450</td>
#       <td id="T_5b176_row1_col3" class="data row1 col3" >0.990851</td>
#       <td id="T_5b176_row1_col4" class="data row1 col4" >0.279753</td>
#       <td id="T_5b176_row1_col5" class="data row1 col5" >0.992835</td>
#       <td id="T_5b176_row1_col6" class="data row1 col6" >0.285468</td>
#       <td id="T_5b176_row1_col7" class="data row1 col7" >0.992289</td>
#       <td id="T_5b176_row1_col8" class="data row1 col8" >0.333927</td>
#     </tr>
#     <tr>
#       <th id="T_5b176_level0_row2" class="row_heading level0 row2" >21</th>
#       <td id="T_5b176_row2_col0" class="data row2 col0" >{'max_df': 0.85, 'min_df': 0.001}</td>
#       <td id="T_5b176_row2_col1" class="data row2 col1" >0.990667</td>
#       <td id="T_5b176_row2_col2" class="data row2 col2" >0.296941</td>
#       <td id="T_5b176_row2_col3" class="data row2 col3" >0.986648</td>
#       <td id="T_5b176_row2_col4" class="data row2 col4" >0.282308</td>
#       <td id="T_5b176_row2_col5" class="data row2 col5" >0.988635</td>
#       <td id="T_5b176_row2_col6" class="data row2 col6" >0.287955</td>
#       <td id="T_5b176_row2_col7" class="data row2 col7" >0.987899</td>
#       <td id="T_5b176_row2_col8" class="data row2 col8" >0.332948</td>
#     </tr>
#     <tr>
#       <th id="T_5b176_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_5b176_row3_col0" class="data row3 col0" >{'max_df': 0.7, 'min_df': 0.0001}</td>
#       <td id="T_5b176_row3_col1" class="data row3 col1" >0.

# %% [markdown]
# ## Params for TF-IDF

# %%
# Separate pipe for finding best params for vectorizer for svc
# this enables us to lower computational complexity

params_grid = dict(min_df=[.0001, .0005, .0007, .001, .005, .01], max_df=[.7, .75, .8, .85, .9])

results = []

for params in tqdm(ParameterGrid(params_grid)):
    tfidf = TfidfVectorizer(token_pattern=r'[A-Za-z]{2,}',
                            max_df=params['max_df'],
                            min_df=params['min_df'],
                            stop_words='english')
    
    tfidf.fit(X_train_text['CleanTweet'])
    X_train_tfidf = tfidf.transform(X_train_text['CleanTweet'])
    X_test_tfidf = tfidf.transform(X_test_text['CleanTweet'])
    
    clf = LinearSVC()
    clf.fit(X_train_tfidf, y_train_text)
    y_pred = clf.predict(X_test_tfidf)
    
    acc = accuracy_score(y_test_text, y_pred)
    
    results.append(dict(
        params=params,
        accuracy=acc
    ))

df = pd.DataFrame(results).sort_values(by='accuracy', ascending=False)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 30/30 [00:48<00:00,  1.62s/it]

# %%
pd.set_option('display.max_colwidth', None)
display(df)
# Out:
#                                 params  accuracy
# 29     {'max_df': 0.9, 'min_df': 0.01}  0.401548
# 5      {'max_df': 0.7, 'min_df': 0.01}  0.401548
# 23    {'max_df': 0.85, 'min_df': 0.01}  0.401548
# 17     {'max_df': 0.8, 'min_df': 0.01}  0.401548
# 11    {'max_df': 0.75, 'min_df': 0.01}  0.401548
# 16    {'max_df': 0.8, 'min_df': 0.005}  0.398167
# 28    {'max_df': 0.9, 'min_df': 0.005}  0.398167
# 4     {'max_df': 0.7, 'min_df': 0.005}  0.398167
# 22   {'max_df': 0.85, 'min_df': 0.005}  0.398167
# 10   {'max_df': 0.75, 'min_df': 0.005}  0.398167
# 27    {'max_df': 0.9, 'min_df': 0.001}  0.395053
# 21   {'max_df': 0.85, 'min_df': 0.001}  0.395053
# 15    {'max_df': 0.8, 'min_df': 0.001}  0.395053
# 3     {'max_df': 0.7, 'min_df': 0.001}  0.395053
# 9    {'max_df': 0.75, 'min_df': 0.001}  0.395053
# 8   {'max_df': 0.75, 'min_df': 0.0007}  0.390604
# 2    {'max_df': 0.7, 'min_df': 0.0007}  0.390604
# 26   {'max_df': 0.9, 'min_df': 0.0007}  0.390604
# 20  {'max_df': 0.85, 'min_df': 0.0007}  0.390604
# 14   {'max_df': 0.8, 'min_df': 0.0007}  0.390604
# 7   {'max_df': 0.75, 'min_df': 0.0005}  0.389803
# 25   {'max_df': 0.9, 'min_df': 0.0005}  0.389803
# 13   {'max_df': 0.8, 'min_df': 0.0005}  0.389803
# 19  {'max_df': 0.85, 'min_df': 0.0005}  0.389803
# 1    {'max_df': 0.7, 'min_df': 0.0005}  0.389803
# 6   {'max_df': 0.75, 'min_df': 0.0001}  0.381618
# 24   {'max_df': 0.9, 'min_df': 0.0001}  0.381618
# 18  {'max_df': 0.85, 'min_df': 0.0001}  0.381618
# 12   {'max_df': 0.8, 'min_df': 0.0001}  0.381618
# 0    {'max_df': 0.7, 'min_df': 0.0001}  0.381618

# %%
#the best params for Extra Trees

params_grid = dict(min_df=[.0001, .0005, .0007, .001, .005, .01], max_df=[.7, .75, .8, .85, .9])

results = []

for params in tqdm(ParameterGrid(params_grid)):
    tfidf = TfidfVectorizer(token_pattern=r'[A-Za-z]{2,}',
                            max_df=params['max_df'],
                            min_df=params['min_df'],
                            stop_words='english')
    
    tfidf.fit(X_train_text['CleanTweet'])
    X_train_tfidf = tfidf.transform(X_train_text['CleanTweet'])
    X_test_tfidf = tfidf.transform(X_test_text['CleanTweet'])
    
    clf = ExtraTreesClassifier()
    clf.fit(X_train_tfidf, y_train_text)
    y_pred = clf.predict(X_test_tfidf)
    
    acc = accuracy_score(y_test_text, y_pred)
    
    results.append(dict(
        params=params,
        accuracy=acc
    ))

df = pd.DataFrame(results).sort_values(by='accuracy', ascending=False)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 30/30 [42:05<00:00, 84.20s/it]

# %%
pd.set_option('display.max_colwidth', None)
display(df)
# Out:
#                                 params  accuracy
# 9    {'max_df': 0.75, 'min_df': 0.001}  0.409022
# 12   {'max_df': 0.8, 'min_df': 0.0001}  0.408844
# 25   {'max_df': 0.9, 'min_df': 0.0005}  0.408488
# 6   {'max_df': 0.75, 'min_df': 0.0001}  0.408310
# 24   {'max_df': 0.9, 'min_df': 0.0001}  0.407688
# 21   {'max_df': 0.85, 'min_df': 0.001}  0.407599
# 19  {'max_df': 0.85, 'min_df': 0.0005}  0.407510
# 27    {'max_df': 0.9, 'min_df': 0.001}  0.406976
# 7   {'max_df': 0.75, 'min_df': 0.0005}  0.406976
# 20  {'max_df': 0.85, 'min_df': 0.0007}  0.406976
# 0    {'max_df': 0.7, 'min_df': 0.0001}  0.406798
# 18  {'max_df': 0.85, 'min_df': 0.0001}  0.406620
# 8   {'max_df': 0.75, 'min_df': 0.0007}  0.406353
# 2    {'max_df': 0.7, 'min_df': 0.0007}  0.406175
# 15    {'max_df': 0.8, 'min_df': 0.001}  0.405374
# 14   {'max_df': 0.8, 'min_df': 0.0007}  0.405196
# 3     {'max_df': 0.7, 'min_df': 0.001}  0.405107
# 1    {'max_df': 0.7, 'min_df': 0.0005}  0.404840
# 26   {'max_df': 0.9, 'min_df': 0.0007}  0.404573
# 13   {'max_df': 0.8, 'min_df': 0.0005}  0.404217
# 10   {'max_df': 0.75, 'min_df': 0.005}  0.394697
# 4     {'max_df': 0.7, 'min_df': 0.005}  0.394163
# 22   {'max_df': 0.85, 'min_df': 0.005}  0.393451
# 16    {'max_df': 0.8, 'min_df': 0.005}  0.393362
# 28    {'max_df': 0.9, 'min_df': 0.005}  0.393184
# 11    {'max_df': 0.75, 'min_df': 0.01}  0.380906
# 5      {'max_df': 0.7, 'min_df': 0.01}  0.378681
# 23    {'max_df': 0.85, 'min_df': 0.01}  0.377970
# 29     {'max_df': 0.9, 'min_df': 0.01}  0.377703
# 17     {'max_df': 0.8, 'min_df': 0.01}  0.377169

# %% [markdown]
# ## ExtraTreesClassifier

# %%
#find the parameters for the model with fixed params of TF-IDF

from sklearn.model_selection import ParameterGrid
from sklearn.pipeline import Pipeline
from tqdm import tqdm
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

params_grid = dict(min_df=[0.0007],
                   max_df=[0.85],
                   max_depth=[6, 7, 8, 9],
                   n_estimators=[100, 200, 300],
                   min_samples_split=[2, 3, 4])

results = []

for params in tqdm(ParameterGrid(params_grid)):
    pipe = Pipeline(steps=[('tf_idf_vec', TfidfVectorizer(token_pattern=r'[A-Za-z]{2,}',
                                                          max_df=params['max_df'],
                                                          min_df=params['min_df'],
                                                          stop_words='english')
                            ),
                           ('classifier', ExtraTreesClassifier(max_depth=params['max_depth'],
                                                                n_estimators=params['n_estimators'],
                                                                min_samples_split=params['min_samples_split']))
                           ])

    pipe.fit(X_train_text['CleanTweet'], y_train_text)

    pipe_preds_train = pipe.predict(X_train_text.CleanTweet)
    pipe_preds_test = pipe.predict(X_test_text.CleanTweet)

    results.append(dict(

        params=params,

        precision_train=precision_score(y_true=y_train_text, y_pred=pipe_preds_train, average='macro'),
        precision_test=precision_score(y_true=y_test_text, y_pred=pipe_preds_test, average='macro'),

        recall_train=recall_score(y_true=y_train_text, y_pred=pipe_preds_train, average='macro'),
        recall_test=recall_score(y_true=y_test_text, y_pred=pipe_preds_test, average='macro'),

        f1_train=f1_score(y_true=y_train_text, y_pred=pipe_preds_train, average='macro'),
        f1_test=f1_score(y_true=y_test_text, y_pred=pipe_preds_test, average='macro'),

        accuracy_train=accuracy_score(y_true=y_train_text, y_pred=pipe_preds_train),
        accuracy_test=accuracy_score(y_true=y_test_text, y_pred=pipe_preds_test)
    ))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 36/36 [02:03<00:00,  3.44s/it]

# %%
results = pd.DataFrame(results)
results.sort_values('accuracy_test', ascending=False).head(10).style.bar(vmin=0, vmax=1)
# Out:
# <style type="text/css">
# #T_a47fd_row0_col1, #T_a47fd_row0_col2, #T_a47fd_row1_col1, #T_a47fd_row1_col2, #T_a47fd_row2_col1, #T_a47fd_row2_col2, #T_a47fd_row3_col1, #T_a47fd_row3_col2, #T_a47fd_row4_col1, #T_a47fd_row4_col2, #T_a47fd_row5_col1, #T_a47fd_row5_col2, #T_a47fd_row6_col1, #T_a47fd_row6_col2, #T_a47fd_row7_col1, #T_a47fd_row7_col2, #T_a47fd_row8_col1, #T_a47fd_row8_col2, #T_a47fd_row9_col1, #T_a47fd_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.7%, transparent 6.7%);
# }
# #T_a47fd_row0_col3, #T_a47fd_row0_col4, #T_a47fd_row1_col3, #T_a47fd_row1_col4, #T_a47fd_row2_col3, #T_a47fd_row2_col4, #T_a47fd_row3_col3, #T_a47fd_row3_col4, #T_a47fd_row4_col3, #T_a47fd_row4_col4, #T_a47fd_row5_col3, #T_a47fd_row5_col4, #T_a47fd_row6_col3, #T_a47fd_row6_col4, #T_a47fd_row7_col3, #T_a47fd_row7_col4, #T_a47fd_row8_col3, #T_a47fd_row8_col4, #T_a47fd_row9_col3, #T_a47fd_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.7%, transparent 16.7%);
# }
# #T_a47fd_row0_col5, #T_a47fd_row0_col6, #T_a47fd_row1_col5, #T_a47fd_row1_col6, #T_a47fd_row2_col5, #T_a47fd_row2_col6, #T_a47fd_row3_col5, #T_a47fd_row3_col6, #T_a47fd_row4_col5, #T_a47fd_row4_col6, #T_a47fd_row5_col5, #T_a47fd_row5_col6, #T_a47fd_row6_col5, #T_a47fd_row6_col6, #T_a47fd_row7_col5, #T_a47fd_row7_col6, #T_a47fd_row8_col5, #T_a47fd_row8_col6, #T_a47fd_row9_col5, #T_a47fd_row9_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.5%, transparent 9.5%);
# }
# #T_a47fd_row0_col7, #T_a47fd_row0_col8, #T_a47fd_row1_col7, #T_a47fd_row1_col8, #T_a47fd_row2_col7, #T_a47fd_row2_col8, #T_a47fd_row3_col7, #T_a47fd_row3_col8, #T_a47fd_row4_col7, #T_a47fd_row4_col8, #T_a47fd_row5_col7, #T_a47fd_row5_col8, #T_a47fd_row6_col7, #T_a47fd_row6_col8, #T_a47fd_row7_col7, #T_a47fd_row7_col8, #T_a47fd_row8_col7, #T_a47fd_row8_col8, #T_a47fd_row9_col7, #T_a47fd_row9_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.0%, transparent 40.0%);
# }
# </style>
# <table id="T_a47fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a47fd_level0_col0" class="col_heading level0 col0" >params</th>
#       <th id="T_a47fd_level0_col1" class="col_heading level0 col1" >precision_train</th>
#       <th id="T_a47fd_level0_col2" class="col_heading level0 col2" >precision_test</th>
#       <th id="T_a47fd_level0_col3" class="col_heading level0 col3" >recall_train</th>
#       <th id="T_a47fd_level0_col4" class="col_heading level0 col4" >recall_test</th>
#       <th id="T_a47fd_level0_col5" class="col_heading level0 col5" >f1_train</th>
#       <th id="T_a47fd_level0_col6" class="col_heading level0 col6" >f1_test</th>
#       <th id="T_a47fd_level0_col7" class="col_heading level0 col7" >accuracy_train</th>
#       <th id="T_a47fd_level0_col8" class="col_heading level0 col8" >accuracy_test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a47fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a47fd_row0_col0" class="data row0 col0" >{'max_depth': 6, 'max_df': 0.85, 'min_df': 0.0007, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_a47fd_row0_col1" class="data row0 col1" >0.066665</td>
#       <td id="T_a47fd_row0_col2" class="data row0 col2" >0.066673</td>
#       <td id="T_a47fd_row0_col3" class="data row0 col3" >0.166667</td>
#       <td id="T_a47fd_row0_col4" class="data row0 col4" >0.166667</td>
#       <td id="T_a47fd_row0_col5" class="data row0 col5" >0.095236</td>
#       <td id="T_a47fd_row0_col6" class="data row0 col6" >0.095244</td>
#       <td id="T_a47fd_row0_col7" class="data row0 col7" >0.399988</td>
#       <td id="T_a47fd_row0_col8" class="data row0 col8" >0.400036</td>
#     </tr>
#     <tr>
#       <th id="T_a47fd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a47fd_row1_col0" class="data row1 col0" >{'max_depth': 6, 'max_df': 0.85, 'min_df': 0.0007, 'min_samples_split': 2, 'n_estimators': 200}</td>
#       <td id="T_a47fd_row1_col1" class="data row1 col1" >0.066665</td>
#       <td id="T_a47fd_row1_col2" class="data row1 col2" >0.066673</td>
#       <td id="T_a47fd_row1_col3" class="data row1 col3" >0.166667</td>
#       <td id="T_a47fd_row1_col4" class="data row1 col4" >0.166667</td>
#       <td id="T_a47fd_row1_col5" class="data row1 col5" >0.095236</td>
#       <td id="T_a47fd_row1_col6" class="data row1 col6" >0.095244</td>
#       <td id="T_a47fd_row1_col7" class="data row1 col7" >0.399988</td>
#       <td id="T_a47fd_row1_col8" class="data row1 col8" >0.400036</td>
#     </tr>
#     <tr>
#       <th id="T_a47fd_level0_row2" class="row_heading level0 row2" >20</th>
#       <td id="T_a47fd_row2_col0" class="data row2 col0" >{'max_depth': 8, 'max_df': 0.85, 'min_df': 0.0007, 'min_samples_split': 2, 'n_estimators': 300}</td>
#       <td id="T_a47fd_row2_col1" class="data row2 col1" >0.066665</td>
#       <td id="T_a47fd_row2_col2" class="data row2 col2" >0.066673</td>
#       <td id="T_a47fd_row2_col3" class="data row2 col3" >0.166667</td>
#       <td id="T_a47fd_row2_col4" class="data row2 col4" >0.166667</td>
#       <td id="T_a47fd_row2_col5" class="data row2 col5" >0.095236</td>
#       <td id="T_a47fd_row2_col6" class="data row2 col6" >0.095244</td>
#       <td id="T_a47fd_row2_col7" class="data row2 col7" >0.399988</td>
#       <td id="T_a47fd_row2_col8" class="data row2 col8" >0.400036</td>
#     </tr>
#     <tr>
#       <th id="T_a47fd_level0_row3" class="row_heading level0 row3" >21</th>
#       <td id="T_a47fd_row3_col0" class="data row3 col0" >{'max_depth': 8, 'max_df': 0.85, 'min_df': 0.0007, 'min_samples_split': 3, 'n_estimators': 100}</td>
#       <td id="T_a47fd_row3_col1" class="data row3 col1" >0.066665</td>
#       <td id="T_a47fd_row3_col2" class="data row3 col2" >0.066673</td>
#       <td id="T_a47fd_row3_col3" class="data row3 col3" >0.166667</td>
#       <td id="T_a47fd_row3_col4" class="data row3 col4" >0.166667</td>
#       <td id="T_a47fd_row3_col5" class="data row3 col5" >0.095236</td>
#       <td id="T_a47fd_row3_col6" class="data row3 col6" >0.095244</td>
#       <td id="T_a47fd_row3_col7" class="data row3 col7" >0.399988</td>
#       <td id="T_a47fd_row3_col8" class="data row3 col8" >0.400036</td>
#     </tr>
#     <tr>
#       <th id="T_a47fd_level0_row4" class="row_heading level0 row4" >22</th>
#       <td id="T_a47fd_row4_col0" class="data row4 col0" >{'max_depth': 8, 'max_df': 0.85, 'min_df': 0.0007, 'min_samples_split': 3, 'n_estimators': 200}</td>
#       <td id="T_a47fd_row4_col1" class="data row4 col1" >0.066665</td>
#       <td id="T_a47fd_row4_col2" class="data row4 col2" >0.066673</td>
#       <td id="T_a47fd_row4_col3" class="data row4 col3" >0.166667</td>
#       <td id="T_a47fd_row4_col4" class="data row4 col4" >0.166667</td>
#       <td id="T_a47fd_row4_col5" class="data row4 col5" >0.095236</td>
#       <td id="T_a47fd_row4_col6" class="data row4 col6" >0.095244</td>
#       <td id="T_a47fd_row4_col7" class="data row4 col7" >0.399988</td>
#       <td id="T_a47fd_row4_col8" class="data row4 col8" >0.400036</td>
#     </tr>
#     <tr>
#       <th id="T_a47fd_level0_row5" class="row_heading level0 row5" >23</th>
#       <td id="T_a47fd_row5_col0" class="data row5 col0" >{'max_depth': 8, 'max_df': 0.85, 'min_df': 0.0007, 'min_samples_split': 3, 'n_estimators': 300}</td>
#       <td id="T_a47fd_row5_col1" class="data row5 col1" >0.066665</td>
#       <td id="T_a47fd_row5_col2" class="data row5 col2" >0.066673</td>
#       <td id="T_a47fd_row5_col3" class="data row5 col3" >0.166667</td>
#       <td id="T_a47fd_row5_col4" class="data row5 col4" >0.166667</td>
#       <td id="T_a47fd_row5_col5" class="data row5 col5" >0.095236</td>
#       <td id="T_a47fd_row5_col6" class="data row5 col6" >0.095244</td>
#       <td id="T_a47fd_row5_col7" class="data row5 col7" >0.399988</td>
#       <td id="T_a47fd_row5_col8" class="data row5 col8" >0.400036</td>
#     </tr>
#     <tr>
#       <th id="T_a47fd_level0_row6" class="row_heading level0 row6" >24</th>
#       <td id="T_a47fd_row6_col0" class="data row6 col0" >{'max_depth': 8, 'max_df': 0.85, 'min_df': 0.0007, 'min_samples_

# %% [markdown]
# ## SVC

# %%
from sklearn.svm import SVC

params_grid = dict(min_df=[0.0005],
                   max_df=[0.85],
                   C=[1, 10, 100],
                   gamma=[0.1, 0.01, 0.001],
                   kernel=['linear', 'rbf'])

results = []

for params in tqdm(ParameterGrid(params_grid)):
    pipe = Pipeline(steps=[('tf_idf_vec', TfidfVectorizer(token_pattern=r'[A-Za-z]{2,}',
                                                          max_df=params['max_df'],
                                                          min_df=params['min_df'],
                                                          stop_words='english')
                            ),
                           ('classifier', SVC(C=params['C'],
                                               gamma=params['gamma'],
                                               kernel=params['kernel']))
                           ])

    pipe.fit(X_train_text['CleanTweet'], y_train_text)

    pipe_preds_train = pipe.predict(X_train_text.CleanTweet)
    pipe_preds_test = pipe.predict(X_test_text.CleanTweet)

    results.append(dict(

        params=params,

        precision_train=precision_score(y_true=y_train_text, y_pred=pipe_preds_train, average='macro'),
        precision_test=precision_score(y_true=y_test_text, y_pred=pipe_preds_test, average='macro'),

        recall_train=recall_score(y_true=y_train_text, y_pred=pipe_preds_train, average='macro'),
        recall_test=recall_score(y_true=y_test_text, y_pred=pipe_preds_test, average='macro'),

        f1_train=f1_score(y_true=y_train_text, y_pred=pipe_preds_train, average='macro'),
        f1_test=f1_score(y_true=y_test_text, y_pred=pipe_preds_test, average='macro'),

        accuracy_train=accuracy_score(y_true=y_train_text, y_pred=pipe_preds_train),
        accuracy_test=accuracy_score(y_true=y_test_text, y_pred=pipe_preds_test)
    ))
# Out:
#  72%|███████████████████████████████████████████████████████▌                     | 13/18 [2:04:18<1:27:03, 1044.77s/it]

# %%
results = pd.DataFrame(results)
results.sort_values('accuracy_test', ascending=False).head(10).style.bar(vmin=0, vmax=1)

# %% [markdown]
# # Results

# %% [markdown]
# |  Model                |  Accuracy train |  Accuracy test |
# |-----------------------|-------------------|----------------|
# | SVC                   |  98%         |  63%     |
# | DecisionTreeClassifier|  99%        |  33%     |
# | ExtraTreesClassifier  |  39%         |  40%      |

# %%
results.append(dict(
params=params,
precision_train=precision_score(y_true=y_train_text, y_pred=pipe_preds_train, average='macro'),
recall_train=recall_score(y_true=y_train_text, y_pred=pipe_preds_train, average='macro'),
f1_train=f1_score(y_true=y_train_text, y_pred=pipe_preds_train, average='macro'),
accuracy_train=accuracy_score(y_true=y_train_text, y_pred=pipe_preds_train),
))

# %%
pd.DataFrame(pipe_preds_test).to_csv('result_tweet.csv',sep=',')

# %%
results = pd.DataFrame(results)
results.sort_values('accuracy_test', ascending=False).head(10).style.bar(vmin=0, vmax=1)
